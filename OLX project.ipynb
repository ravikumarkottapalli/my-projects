# %%
import requests
import re
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
path = r"C:\Users\RAVI\Downloads\edgedriver_win64 2\msedgedriver.exe"

# %%
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options

# %%
service = Service(executable_path = path)
options = webdriver.EdgeOptions()

# %%
driver = webdriver.Edge(service=service, options= options)

# %%
driver.get("https://www.olx.in/en-in/hyderabad_g4058526/motorcycles_c81?page1")

# %%
driver.page_source
# Out:
# '<html lang="en" data-rh="lang" class="_2yqpe"><head>\n        <meta charset="utf-8">\n        <title>Buy &amp; Sell Second Hand Bikes in Hyderabad, Used Motorcycles in Hyderabad | OLX</title>\n        <meta data-rh="true" name="description" content="Find the best Second Hand Bikes price in Hyderabad! Used Bikes for sale in Hyderabad. Sell your used Old Bike, Royal Enfield, Harley Davidson, KTM, Yamaha, Pulsar &amp; more with OLX Hyderabad. ओएलएक्स बाइक Hyderabad!">\n        <link data-rh="true" rel="canonical" href="https://www.olx.in/en-in/hyderabad_g4058526/motorcycles_c81">\n       \n        <meta http-equiv="Content-Language" content="en-IN">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <meta http-equiv="cleartype" content="on">\n        <meta name="HandheldFriendly" content="True">\n        <meta name="MobileOptimized" content="320">\n        <meta name="google-site-verification" content="yVwhHrKjufVXHFEeBCU1bMn3QrFBkRGbO-YLes1GhWA">\n       
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(driver.page_source,"html.parser")

# %%
soup
# Out:
# <html class="_2yqpe" data-rh="lang" lang="en"><head>
# <meta charset="utf-8"/>
# <title>Buy &amp; Sell Second Hand Bikes in Hyderabad, Used Motorcycles in Hyderabad | OLX</title>
# <meta content="Find the best Second Hand Bikes price in Hyderabad! Used Bikes for sale in Hyderabad. Sell your used Old Bike, Royal Enfield, Harley Davidson, KTM, Yamaha, Pulsar &amp; more with OLX Hyderabad. ओएलएक्स बाइक Hyderabad!" data-rh="true" name="description"/>
# <link data-rh="true" href="https://www.olx.in/en-in/hyderabad_g4058526/motorcycles_c81" rel="canonical"/>
# <meta content="en-IN" http-equiv="Content-Language"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="320" name="MobileOptimized"/>
# <meta content="yVwhHrKjufVXHFEeBCU1bMn3QrFBkRGbO-YLes1GhWA" name="google-site-verification"/>
# ...

# %%
for i in soup.find_all("div",class_="fTZT3"):
    print(i.text)
# Out:
# Featured₹ 98,0002021 - 12,100 kmPulsar 150 dual disc black redKukatpally, HyderabadJun 01
# Featured₹ 13,0002024 - 0 kmSuzuki access 125cc At Lowest Down PaymentKukatpally, HyderabadJul 02
# Featured₹ 1,89,0002023 - 10,744 kmKTM Duke 200 2023 10744 kms drivenBharat Nagar, HyderabadMay 25
# ₹ 68,0002022 - 7,000 kmTVS Sport, model 2022, less driven kms 7000, excellent conditionSundar Nagar, HyderabadToday
# ₹ 1,38,0002019 - 20,000 kmYamaha R15, model 2019, less driven kms 20k, excellent conditionKukatpally, HyderabadToday
# ₹ 1,70,0002022 - 7,000 kmYamaha R15 version 3, model 2022, less driven kms 7k, good conditionBegumpet, HyderabadToday
# ₹ 92,0002022 - 20,000 kmSuzuki Burgman, model 2022, excellent condition, less driven kms 20kKukatpally, HyderabadToday
# ₹ 1,90,0002020 - 11,000 kmAdarsh Motors, Royal Enfield classic 350, model 2020, less kms 11kBegumpet, HyderabadToday
# ₹ 53,5002016 - 27,000 kmBajaj Avenger 150 Street, model 2016, excellent conditionBorabanda, HyderabadToday
# ...

# %%
for i in soup.find_all("span",class_="_2Ks63"):
    print(i.text)
# Out:
# ₹ 98,000
# ₹ 13,000
# ₹ 1,89,000
# ₹ 68,000
# ₹ 1,38,000
# ₹ 1,70,000
# ₹ 92,000
# ₹ 1,90,000
# ₹ 53,500
# ₹ 93,000
# ₹ 1,90,000
# ₹ 2,15,000
# ₹ 2,45,000
# ₹ 13,999
# ₹ 25,000
# ₹ 1,38,000
# ₹ 20,000
# ₹ 86,999
# ₹ 80,000
# ₹ 2,15,000

# %%
for i in soup.find_all("span",class_="YBbhy"):
    print(i.text)
# Out:
# 2021 - 12,100 km
# 2024 - 0 km
# 2023 - 10,744 km
# 2022 - 7,000 km
# 2019 - 20,000 km
# 2022 - 7,000 km
# 2022 - 20,000 km
# 2020 - 11,000 km
# 2016 - 27,000 km
# 2023 - 10,000 km
# 2020 - 15,000 km
# 2022 - 8,000 km
# 2023 - 3,000 km
# 2024 - 0 km
# 2024 - 0 km
# 2021 - 24,520 km
# 2024 - 0 km
# 2014 - 29,600 km
# 2020 - 31,560 km
# 2023 - 21,075 km

# %%
for i in soup.find_all("span",class_="_2poNJ"):
    print(i.text)
# Out:
# Pulsar 150 dual disc black red
# Suzuki access 125cc At Lowest Down Payment
# KTM Duke 200 2023 10744 kms driven
# TVS Sport, model 2022, less driven kms 7000, excellent condition
# Yamaha R15, model 2019, less driven kms 20k, excellent condition
# Yamaha R15 version 3, model 2022, less driven kms 7k, good condition
# Suzuki Burgman, model 2022, excellent condition, less driven kms 20k
# Adarsh Motors, Royal Enfield classic 350, model 2020, less kms 11k
# Bajaj Avenger 150 Street, model 2016, excellent condition
# Honda Shine SP 125, model 2023, less driven kms, 10k, good condition
# Royal Enfield classic 350, model 2020,lessdriven kms 15k,goodcondition
# Royal Enfield classic 350, model 2022,less driven kms 8k,goodcondition
# Royal Enfield classic 350, model 2023, excellent condition,kms 300k
# Bajaj Platinum 100cc At Lowest Dp
# New Bluetooth Version Split Seat Bajaj 150cc
# Jawa 42 black colour showroom condition
# New pulsar 150 low down payment 20000/
# ...

# %%
for i in soup.find_all("span",class_="_2VQu4"):
    print(i.text)
# Out:
# Kukatpally, Hyderabad
# Kukatpally, Hyderabad
# Bharat Nagar, Hyderabad
# Sundar Nagar, Hyderabad
# Kukatpally, Hyderabad
# Begumpet, Hyderabad
# Kukatpally, Hyderabad
# Begumpet, Hyderabad
# Borabanda, Hyderabad
# Borabanda, Hyderabad
# Begumpet, Hyderabad
# Begumpet, Hyderabad
# Begumpet, Hyderabad
# Balkampet, Hyderabad
# JNTU, Hyderabad
# Kukatpally, Hyderabad
# Jagadgiri Gutta, Hyderabad
# Kukatpally, Telangana
# Kukatpally, Hyderabad
# Kukatpally, Hyderabad

# %%
for i in soup.find_all("span",class_="_2jcGx"):
    print(i.text)
# Out:
# Jun 01
# Jul 02
# May 25
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today
# Today

# %%
for i in soup.find_all("span",class_="TIvlD"):
    print(i.text)
# Out:
# Featured
# Featured
# Featured
# Featured
# Featured
# Featured
